# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.0/721.0 kB 4.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
import shutil
import zipfile

# %%
shutil.copytree("/content/drive/MyDrive/Prince", "/content/prince")
# Out:
# '/content/prince'

# %%
model=YOLO()
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 79.0MB/s]

# %%
zipis=zipfile.ZipFile("/content/prince/datasets.zip",'r')
zipis.extractall('/content')

# %%
zipis.close()

# %%
os.listdir(os.getcwd())
# Out:
# ['.config', 'yolov8n.pt', 'prince', 'drive', 'datasets', 'sample_data']

# %%
result=model.train(data="/content/prince/data_info.yaml",epochs=200)
# Out:
# Ultralytics YOLOv8.1.25 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
shutil.copytree("/content/runs/detect/train/weights", "/content/drive/MyDrive/Prince/weights")
# Out:
# '/content/drive/MyDrive/Prince/weights'
