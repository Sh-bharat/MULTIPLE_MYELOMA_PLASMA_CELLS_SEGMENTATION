# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.0/721.0 kB 9.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
import shutil
import zipfile

# %%
shutil.copytree("/content/drive/MyDrive/Cancer_Cell_Detection/Temp_Model", "/content/Temp_Model")
# Out:
# '/content/Temp_Model'

# %%
model=YOLO()
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 128MB/s]

# %%
zipis=zipfile.ZipFile("/content/Temp_Model/datasets.zip",'r')
zipis.extractall('/content')

# %%
zipis.close()

# %%
result=model.train(data="/content/Temp_Model/data_info.yaml",epochs=500)
# Out:
# Ultralytics YOLOv8.1.26 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
shutil.copytree("/content/runs/detect/train/weights", "/content/drive/MyDrive/Cancer_Cell_Detection/Temp_weights")
# Out:
# '/content/drive/MyDrive/Cancer_Cell_Detection/Temp_weights'
